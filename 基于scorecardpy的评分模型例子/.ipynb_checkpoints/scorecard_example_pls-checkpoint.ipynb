# %%
import pandas as pd
import numpy as np
import warnings
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)
warnings.filterwarnings('ignore')

# %%
import pandas as pd
#读入字段解释数据并处理成以指标为index的DataFrame
dd=pd.read_excel('illustration.XLSX',skiprows=[0]).fillna(method='ffill').drop([0])
dicts=pd.DataFrame(dd.reset_index(drop=True).values,columns=['illus2','vars','illus1','logical_illus'])
dicts.set_index('vars',drop=True)
dicts=dicts[['vars','illus1','illus2','logical_illus']].set_index('vars',drop=True)
# dicts.reset_index(inplace=True)
dicts.head(2)
# Out:
#       illus1     illus2 logical_illus
# vars
# y       是否逾期      被解释变量    0-未逾期 1-逾期
# x_001     性别  身份信息及财产状况       0-男，1-女

# %%
# Traditional Credit Scoring Using Logistic Regression
import scorecardpy as sc
import pandas as pd
# # data prepare ------
# # load germancredit data
dat =pd.read_csv('train_data.csv')
dt_s=dat.copy()
# # filter variable via missing rate, iv, identical value rate
# #dt_s = sc.var_filter(dat, y="y")
# #xcol=dat.columns.to_list()[3:20]
# #dt_s = sc.var_filter(dat, y="y",x=xcol)              #--------------return a DataFrame only filters out from [x]
# dt_s = sc.var_filter(dat, y="y")
# #dt_s = sc.var_filter(dat, y="y",return_rm_reason=True) #-------------return a dict(2 DataFrame) with keys:['dt','rm']

# %%
dts_s1=dt_s.drop(columns=['user_id','x_012','x_103'])
dts_s1.shape
# Out:
# (7761, 198)

# %%
##去除多重共线性
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif(x, thres=10.0):
    X_m = np.matrix(x)
    VIF_list = [variance_inflation_factor(X_m, i) for i in range(X_m.shape[1])]
    maxvif=pd.DataFrame(VIF_list,index=x.columns,columns=["vif"])
    col_save=list(maxvif[maxvif.vif<=float(thres)].index)
    col_delete=list(maxvif[maxvif.vif>float(thres)].index)
    print(maxvif)
    print('delete Variables:', col_delete)
    return x[col_save]

# %%
ddx=dts_s1.fillna(0)
ddy=vif(ddx,thres=10.)
# Out:
#                 vif
# y      1.517883e+00
# x_001  1.242250e+00
# x_002  9.859883e+00
# x_003  1.622410e+00
# x_004  1.881701e+00
# x_005  1.126242e+00
# x_006  1.629957e+00
# x_007  1.100605e+00
# x_008  1.078509e+00
# x_009  2.749645e+01
# x_010  1.453409e+01
# x_011  2.149890e+00
# x_013  1.134337e+01
# x_014  1.796130e+01
# x_015  1.095624e+00
# x_016  2.110593e+00
# x_017  1.082641e+00
# x_018  1.437623e+01
# x_019  1.057755e+00
# x_020  2.627143e+04
# x_021  2.204051e+04
# x_022  1.408312e+00
# x_023  3.572528e+00
# x_024  2.480015e+01
# x_025  2.404739e+02
# x_026  2.511052e+02
# x_027  1.151787e+01
# x_028  1.375942e+00
# x_029  6.016197e+01
# x_030  1.832797e+02
# x_031  2.489918e+02
# x_032  2.330005e+01
# x_033  9.921536e+00
# x_034  2.820082e+04
# x_035  1.800378e+04
# x_036  5.168683e+02
# x_037  6.405761e+01
# x_038  2.638042e+01
# x_039  2.257102e+00
# x_040  1.120248e+00
# x_041  9.662250e+01
# x_042  4.048181e+01
# x_043  7.903495e+01
# x_044  2.167389e+00
# x_045  2.937569e+02
# x_046  2.003900e+02
# x_047  4.635427e+01
# x_048  7.953158e+00
# x_049  6.169028e+00
# x_050  6.306768e+00
# x_051  1.402208e+00
# x_052  1.564876e+01
# x_053  2.067287e+01
# x_054  4.520567e+00
# x_055  2.093425e+02
# x_056  4.989730e+01
# x_057  1.318668e+02
# x_058  2.558332e+00
# x_059  3.621700e+02
# x_060  2.087922e+02
# x_061  7.297715e+00
# x_062  5.389346e+00
# x_063  5.181288e+00
# x_064  1.947158e+00
# x_065  3.973912e+00
# x_066  2.604870e+00
# x_067  2.673188e+00
# x_068  2.203865e+00
# x_069  2.245486e+00
# x_070  2.031575e+00
# x_071  5.267782e+00
# x_072  5.766211e+00
# x_073  1.449247e+00
# x_074  2.978422e+02
# x_075  1.522322e+02
# x_076  2.739093e+02
# x_077  1.234283e+01
# x_078  1.103578e+02
# x_079  1.563324e+02
# x_080  2.530560e+00
# x_081  1.839124e+01
# x_082  5.657276e+00
# x_083  1.282614e+01
# x_084  1.438115e+00
# x_085  3.291674e+01
# x_086  2.768948e+01
# x_087  1.501091e+00
# x_088  5.503848e+00
# x_089  4.785544e+00
# x_090  5.134540e+00
# x_091  1.395869e+00
# x_092  1.304288e+01
# x_093  1.020959e+01
# x_094  6.404488e+00
# x_095  1.757736e+00
# x_096  5.235471e+00
# x_097  4.904115e+00
# x_098  5.735844e+00
# x_099  1.602176e+00
# x_100  1.540339e+01
# x_101  1.421184e+00
# x_102  1.699087e+00
# x_104  2.431714e+01
# x_105  1.293485e+01
# x_106  1.018130e+01
# x_107  4.394172e+00
# x_108  1.834938e+00
# x_109  9.982461e+00
# x_110  1.420657e+01
# x_111  3.301854e+00
# x_112  2.036536e+00
# x_113  1.680513e+00
# x_114  1.289013e+00
# x_115  3.072277e+02
# x_116  3.083977e+02
# x_117  1.735202e+00
# x_118  1.738090e+01
# x_119  1.877879e+01
# x_120  1.850723e+00
# x_121  3.278713e+02
# x_122  1.600164e+02
# x_123  2.435048e+02
# x_124  1.240424e+01
# x_125  4.417238e+02
# x_126  2.417082e+02
# x_127  2.617263e+00
# x_128  6.736042e+00
# x_129  7.566929e+00
# x_130  1.700752e+00
# x_131  5.326957e+00
# x_132  1.223770e+01
# x_133  2.590997e+01
# x_134  1.736834e+01
# x_135  2.236217e+01
# x_136  3.340419e+00
# x_137  1.709511e+01
# x_138  4.043838e+01
# x_139  3.441805e+01
# x_140  2.446994e+01
# x_141  5.481356e+00
# x_142  1.732959e+01
# x_143  3.075332e+01
# x_144  2.885512e+01
# x_145  1.430761e+01
# x_146  4.752745e+00
# x_147  5.080129e+00
# x_148  1.728146e+00
# x_149  3.384094e+01
# x_150  2.392870e+01
# x_151  6.341114e+01
# x_152  5.502807e+01
# x_153           inf
# x_154           inf
# x_155           inf
# x_156  2.664274e+02
# x_157  5.219315e+02
# x_158  2.558965e+02
# x_159  6.491627e+00
# x_160  6.934229e+00
# x_161  3.044745e+00
# x_162  7.222380e+01
# x_163  4.553172e+01
# x_164  1.305126e+02
# x_165  1.114506e+02
# x_166           inf
# x_167           inf
# x_168           inf
# x_169  4.543388e+02
# x_170  6.783189e+02
# x_171  4.101985e+02
# x_172  3.202099e+01
# x_173  7.238006e+00
# x_174  3.168236e+00
# x_175  7.867106e+01
# x_176  5.348226e+01
# x_177  1.261560e+02
# x_178  1.086966e+02
# x_179           inf
# x_180           inf
# x_181           inf
# x_182  2.621344e+02
# x_183  1.866398e+02
# x_184  2.307159e+02
# x_185  5.019951e+01
# x_186  7.481272e+00
# x_187  2.179012e+00
# x_188  2.087115e+02
# x_189  2.086583e+02
# x_190  1.007023e+02
# x_191  7.826447e+01
# x_192  5.691577e+02
# x_193  5.586858e+02
# x_194  2.878174e+02
# x_195  2.650838e+02
# x_196  5.345085e+02
# x_197  5.264814e+02
# x_198  2.195473e+02
# x_199  2.123670e+02
# delete Variables: ['x_009', 'x_010', 'x_013', 'x_014', 'x_018', 'x_020', 'x_021', 'x_024', 'x_025', 'x_026', 'x_027', 'x_029', 'x_030', 'x_031', 'x_032', 'x_034', 'x_035', 'x_036', 'x_037', 'x_038', 'x_041', 'x_042', 'x_043', 'x_045', 'x_046', 'x_047', 'x_052', 'x_053', 'x_055', 'x_056', 'x_057', 'x_059', 'x_060', 'x_074', 'x_075', 'x_076', 'x_077', 'x_078', 'x_079', 'x_081', 'x_083', 'x_085', 'x_086', 'x_092', 'x_093', 'x_100', 'x_104', 'x_105', 'x_106', 'x_110', 'x_115', 'x_116', 'x_118', 'x_119', 'x_121', 'x_122', 'x_123', 'x_124', 'x_125', 'x_126', 'x_132', 'x_133', 'x_134', 'x_135', 'x_137', 'x_138', 'x_139', 'x_140', 'x_142', 'x_143', 'x_144', 'x_145', 'x_149', 'x_150', 'x_151', 'x_152', 'x_153', 'x_154', 'x_155', 'x_156', 'x_157', 'x_158', 'x_162', 'x_163', 'x_164', 'x_165', 'x_166', 'x_167', 'x_168', 'x_169', 'x_170', 'x_171', 'x_172', 'x_175', 'x_176', 'x_177', 'x_178', 'x_179', 'x_180', 'x_181', 'x_182', 'x_183', 'x_184', 'x_185', 'x_188', 'x_189', 'x_190', 'x_191', 'x_192', 'x_193', 'x_194', 'x_195', 'x_196', 'x_197', 'x_198', 'x_199']

# %%
ddy.shape
# Out:
# (7761, 82)

# %%
# special_values = {'x_018':[1]}
# bins = sc.woebin(dt_s,y="y",x=["x_018"],special_values=special_values)
bins=sc.woebin(ddy,y="y")
plots=sc.woebin_plot(bins)
# Out:
# [INFO] creating woe binning ...
# Binning on 7761 rows and 82 columns in 00:00:51

# %%
# sc.iv(dt_s, 'y', ['x_003'], order=False)

# %%
#print(bins['x_003'])
#print(pd.cut(dt_s['x_003'],[float('-inf'),0,float('inf')],right=False).sort_values())
#.astype(str).value_counts()

# %%
import numpy as np
#np.sort([bins[x].total_iv.unique()[0] for x in bins.keys()])
feature_iv=pd.DataFrame([[k,v.total_iv[0]] for k,v in bins.items()],columns=['feature','iv']).sort_values(by='iv',ascending=False)
feature_iv['illus']=[dicts.loc[x]['illus1'] for x in feature_iv['feature']]
feature_iv
# Out:
#    feature        iv               illus
# 1    x_127  0.581775   近6个月金融类消费金额均值/标准差
# 17   x_080  0.391895   近6个月互联网交易金额均值/标准差
# 55   x_173  0.316757       90天内单笔还款金额最大值
# 52   x_136  0.298940       30天内单笔放款金额最小值
# 68   x_174  0.295358       90天内单笔还款金额最小值
# 66   x_061  0.293018    近6个月异地交易金额均值/标准差
# 3    x_160  0.289187       30天内单笔还款金额最大值
# 74   x_131  0.288323            最近一笔放款金额
# 41   x_159  0.285252          30天内成功还款金额
# 4    x_161  0.278263       30天内单笔还款金额最小值
# 21   x_058  0.254246    近6个月异地交易笔数均值/标准差
# 33   x_186  0.254183      180天内单笔还款金额最大值
# 25   x_147  0.239517          最近一笔成功还款金额
# 46   x_044  0.233566      近6个月交易笔数均值/标准差
# 63   x_148  0.195707          最近一笔失败还款金额
# 9    x_141  0.172636       90天内单笔放款金额最小值
# 26   x_187  0.164637      180天内单笔还款金额最小值
# 57   x_088  0.063441          近6个月交易失败次数
# 27   x_146  0.062813      180天内单笔放款金额最小值
# 64   x_089  0.055058        近6个月有交易失败月份数
# 15   x_091  0.054862    近6个月交易失败笔数均值/标准差
# 14   x_090  0.052696        近6个月交易失败笔数均值
# 72   x_051  0.034861   近6个月信用卡交易笔数均值/标准差
# 28   x_066  0.033801        近6个月有夜间交易月份数
# 51   x_048  0.030626         近6个月信用卡交易笔数
# 12   x_049  0.030040       近6个月有信用卡交易月份数
# 5    x_002  0.029604                  年龄
# 30   x_050  0.027381       近6个月信用卡交易笔数均值
# 65   x_054  0.015230   近6个月信用卡交易金额均值/标准差
# 44   x_033  0.012388            持贷记卡最高等级
# 34   x_097  0.005673        近6个月有余额不足月份数
# 48   x_098  0.005673        近6个月余额不足次数均值
# 75   x_082  0.003070        近6个月有大额交易月份数
# 80   x_113  0.002029       近6个月有商旅类交易月份数
# 47   x_094  0.000354        近6个月密码输出次数均值
# 37   x_128  0.000008         近6个月加油类交易笔数
# 38   x_129  0.000008       近6个月有加油类交易月份数
# 76   x_001  0.000000                  性别
# 73   x_003  0.000000                是否有房
# 70   x_069  0.000000         近有公共事业交费月份数
# 79   x_063  0.000000       近6个月有信用卡还款月份数
# 56   x_107  0.000000       近6个月汽车类月均交易笔数
# 69   x_028  0.000000         贷记卡（钻石）持卡数量
# 67   x_109  0.000000         近6个月保险类交易笔数
# 58   x_015  0.000000                基金标志
# 54   x_004  0.000000                是否有车
# 71   x_120  0.000000         近6个月教育类消费金额
# 59   x_117  0.000000       近6个月家装建材类交易金额
# 78   x_067  0.000000          近6个月夜间交易金额
# 77   x_064  0.000000         近6个月信用卡还款金额
# 60   x_065  0.000000          近6个月夜间交易笔数
# 61   x_101  0.000000        近6个月有金额超限月份数
# 62   x_102  0.000000        近6个月房地产类交易笔数
# 0    x_007  0.000000              珠宝消费标志
# 53   x_008  0.000000              婚庆消费标志
# 22   x_016  0.000000               信托类标志
# 2    x_062  0.000000         近6个月信用卡还款笔数
# 6    x_087  0.000000    近6个月大额交易金额均值/标准差
# 7    x_112  0.000000         近6个月商旅类交易金额
# 8    x_023  0.000000         借记卡（白金）持卡数量
# 10   x_095  0.000000    近6个月密码输错次数均值/标准差
# 11   x_070  0.000000        近6个月公共事业交费金额
# 13   x_130  0.000000         近6个月加油类交易金额
# 16   x_068  0.000000        近6个月公共事业交费笔数
# 18   x_039  0.000000             外资银行卡片数
# 19   x_099  0.000000  近6个月余额不足次数变异均值/标准差
# 20   x_011  0.000000               人身险标志
# 23   x_084  0.000000    近6个月大额交易笔数均值/标准差
# 50   x_017  0.000000             资产管理类标志
# 24   x_096  0.000000          近6个月余额不足次数
# 29   x_072  0.000000          近6个月有缴税月份数
# 31   x_071  0.000000            近6个月缴税笔数
# 32   x_108  0.000000         近6个月汽车类交易金额
# 35   x_005  0.000000                是否有孩
# 36   x_006  0.000000               高消费标志
# 39   x_019  0.000000           有无母婴/教育消费
# 42   x_111  0.000000         近6个月保险类交易金额
# 43   x_114  0.000000         近6个月商旅类交易金额
# 45   x_073  0.000000            近6个月缴税金额
# 49   x_022  0.000000         借记卡（钻石）持卡数量
# 40   x_040  0.000000             其他银行卡片数

# %%
model_features=feature_iv[feature_iv.iv > 0.1].feature.to_list() 
ddy_after_vif=ddy[model_features+['y']]
bins=sc.woebin(ddy_after_vif,y='y')
# Out:
# [INFO] creating woe binning ...
# Binning on 7761 rows and 18 columns in 00:00:25

# %%
binsx={}
for x in model_features:
    binsx[x]=bins[x]

# %%
plots=sc.woebin_plot(binsx)

# %%
biny=sc.woebin_adj(ddy_after_vif, y="y", bins=bins)
# Out:
# -------- 1/16 x_044 --------
# >>> dt[x_044].describe():
# count    7761.000000
# mean       10.892852
# std        35.055903
# min         0.000000
# 25%         0.993246
# 50%         1.546402
# 75%         2.270082
# max       600.000000
# Name: x_044, dtype: float64
# >>> Current breaks:
# 1.0,2.0,7.0
# >>> Adjust breaks for (1/16) x_044?
# 1: next
# 2: yes
# 3: back
# Selection: 2
# >>> Enter modified breaks: 2.0
# [INFO] creating woe binning ...
# >>> Current breaks:
# 2.0
# >>> Adjust breaks for (1/16) x_044?
# 1: next
# 2: yes
# 3: back
# Selection: 1
# -------- 2/16 x_058 --------
# >>> dt[x_058].describe():
# count    7761.000000
# mean       10.522347
# std        36.879697
# min         0.000000
# 25%         0.000000
# 50%         1.430983
# 75%         2.227766
# max      1200.000000
# Name: x_058, dtype: float64
# >>> Current breaks:
# 1.0,2.0,7.0
# >>> Adjust breaks for (2/16) x_058?
# 1: next
# 2: yes
# 3: back
# Selection: y
# --------------------------------------------------
# ValueError       Traceback (most recent call last)
# <ipython-input-84-2b6b20f9e1a0> in <module>
# ----> 1 biny=sc.woebin_adj(ddy_after_vif, y="y", bins=bins)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scorecardpy\woebin.py in woebin_adj(dt, y, bins, adj_all_var, special_values, method, save_breaks_list, count_distr_limit)
#    1453         woebin_adj_print_basic_info(i, xs_adj, bins, dt, bins_breakslist)
#    1454         # adjusting breaks ------
# -> 1455         adj_brk = menu(i, xs_len, x_i)
#    1456         if adj_brk == 0:
#    1457             return
#
# C:\ProgramData\Anaconda3\lib\site-packages\scorecardpy\woebin.py in menu(i, xs_len, x_i)
#    1433         print('1: next \n2: yes \n3: back')
#    1434         adj_brk = input("Selection: ")
# -> 1435         adj_brk = int(adj_brk)
#    1436         if adj_brk not in [0,1,2,3]:
#    1437             warnings.warn('Enter an item from the menu, or 0 to exit.')
#
# ValueError: invalid literal for int() with base 10: 'y'

# %%
# biny=sc.woebin(ddy_after_vif,'y')
# Out:
# [INFO] creating woe binning ...
# Binning on 7761 rows and 18 columns in 00:00:25

# %%
train, test = sc.split_df(ddy_after_vif, 'y').values()

# %%
# binning adjustment
# # adjust breaks interactively
# breaks_adj = sc.woebin_adj(dt_s, "creditability", bins) 
# # or specify breaks manually
# breaks_adj = {
#     'x_003': [26, 35],
#     'other.debtors.or.guarantors': ["none", "co-applicant%,%guarantor"]
# }
# bins_adj = sc.woebin(dt_s, y="y", x="x_003", breaks_list={"x_003":[0.5]})
# sc.woebin_plot(bins_adj)
# bins=sc.woebin(dt_s, y="y", x="x_003")
# sc.woebin_plot(bins_adj)

# %%
# converting train and test into woe values
train_woe = sc.woebin_ply(train, binsx)
test_woe = sc.woebin_ply(test, binsx)

y_train = train_woe.loc[:,'y']
X_train = train_woe.loc[:,train_woe.columns != 'y']
y_test = test_woe.loc[:,'y']
X_test = test_woe.loc[:,train_woe.columns != 'y']
# Out:
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...

# %%
# logistic regression ------
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(penalty='l1', C=0.9, solver='saga', n_jobs=-1)
lr.fit(X_train, y_train)
# lr.coef_
# lr.intercept_

# predicted proability
train_pred = lr.predict_proba(X_train)[:,1]
test_pred = lr.predict_proba(X_test)[:,1]

# %%
# performance ks & roc ------
train_perf = sc.perf_eva(y_train, train_pred, title = "train")
test_perf = sc.perf_eva(y_test, test_pred, title = "test")

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
X = X_train
y = y_train
X2 = sm.add_constant(X)
# est = sm.OLS(y, X2)
# est2 = est.fit()
# print(est2.summary())
sml=sm.Logit(y,X2)
sml1=sml.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.432679
#          Iterations 6

# %%
pd.DataFrame([(x,feature_iv.set_index('feature').iv.loc[x],sml1.params.loc[x+'_woe'],
               sml1.pvalues.loc[x+'_woe']) for x in model_features],
               columns=['vars','iv','cof','P_val'])
# Out:
#      vars        iv       cof         P_val
# 0   x_127  0.581775  0.601806  5.243217e-13
# 1   x_080  0.391895  0.239853  1.136030e-02
# 2   x_173  0.316757  0.257145  1.343885e-01
# 3   x_136  0.298940  0.294307  1.050097e-04
# 4   x_174  0.295358  0.156080  3.404534e-01
# 5   x_061  0.293018 -0.181032  7.966989e-02
# 6   x_160  0.289187  0.304184  3.178966e-01
# 7   x_131  0.288323  0.262664  3.816697e-03
# 8   x_159  0.285252 -0.373063  1.754061e-01
# 9   x_161  0.278263  0.168056  4.713663e-01
# 10  x_058  0.254246  0.082217  5.652110e-01
# 11  x_186  0.254183 -0.130436  3.724934e-01
# 12  x_147  0.239517 -0.205779  2.381710e-01
# 13  x_044  0.233566  0.160323  2.658923e-01
# 14  x_148  0.195707  0.353795  3.409880e-04
# 15  x_141  0.172636  0.040583  6.938295e-01
# 16  x_187  0.164637 -0.061906  6.553887e-01

# %%
# score ------
card = sc.scorecard(bins, lr, X_train.columns)
# credit score
train_score = sc.scorecard_ply(train, card, print_step=0)
test_score = sc.scorecard_ply(test, card, print_step=0)

# %%
# psi
sc.perf_psi(
  score = {'train':train_score, 'test':test_score},
  label = {'train':y_train, 'test':y_test}
)
